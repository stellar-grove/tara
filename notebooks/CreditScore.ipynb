# %% [markdown]
# # Credit Worthiness
# ### Building a model to predict whether applicants are credit worthy or not.

# %% [markdown]
# ## Import the Packages needed

# %%
import sys; sys.path.append("../../")
import tara.stuffs as stuffs
import tara.hub as hub
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Build the credit Object

# %%
credit = hub.CreditScore()

# %% [markdown]
# ## Load the data collected

# %%
credit.loadData()

# %% [markdown]
# ## View what data has been created in the loadData stage

# %% [markdown]
# <i>*Note:</i> 'split_data' contains a list of four DataFrames generated from the test_train split algorithm.

# %%
credit.data.keys()
# Out:
# dict_keys(['CreditScore', 'X', 'y', 'split_data'])

# %% [markdown]
# ## Build the Logistic Regression Model to predict Repayment Status

# %%
credit.BuildModel()

# %% [markdown]
# ## Display the Model in an easily readable way

# %%
print(credit.model["model_words"])
# Out:
# f(x) = 0.0038 * credit_score -0.0003 * income -0.0 * loan_amount -0.0 * age -0.0

# %% [markdown]
# ## State the Accuracy Score of the Model

# %%
credit.model["accuracy_score"]

# %% [markdown]
# ## Show a sampling of the predictions generated by the Model.

# %%
credit.data["predictions"].head()

# %% [markdown]
# ## View the Confusion Matrix in Both Integer and Percent Formats

# %% [markdown]
# ### Integers

# %%
credit.model["confusion_matrix"]

# %% [markdown]
# ### Percent

# %%
credit.model["confusion_pct"]

# %% [markdown]
# ## Print the Confusion Narrative to explain what each of the matrices above mean.

# %%
print(credit.model["confusion_narrative"])
